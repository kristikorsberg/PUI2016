#    -1.37935241e+00   5.42238034e-01  -1.01950799e+00   2.53015579e-04
#     2.18504312e-02   1.90760235e-01  -3.76661152e-01  -3.00445188e-01
#     2.99572706e-01  -1.70881701e+00   4.45027706e-01   1.95784290e-02
#     2.34918557e+00   2.39153020e-01  -1.76740736e+00  -1.24254896e+00
#    -7.79133292e-01   4.87341726e-01   1.12661297e+00  -2.06624402e+00
#    -1.58804620e-01  -5.52075146e-01   1.79353990e+00   6.78307839e-01
#    -4.12405170e-01  -1.64360701e+00  -9.88113481e-01  -1.56770870e+00
#     5.92483560e-01  -1.53857166e+00   4.60207419e-01   5.26547120e-01
#     2.60443615e+00  -1.43620769e+00   1.00727225e+00  -8.50764123e-03
#    -9.43649907e-01  -1.10678320e+00   9.50048113e-01  -1.64080344e+00
#    -1.20894593e+00  -2.23694217e-01   1.53622005e-01   8.62075763e-01]]

# %% [markdown]
# #### if you did this correctly the shape of ReprRand will be (2, 100)

# %%
# run this cell
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
import numpy as np
import random

#create 'reprRandInit' to store values in list
reprRandInit = []
for i in range(50):
    arrayTest = 3 * np.random.randn(2, 100) + 5
    reprRandInit.append(arrayTest)
reprRandAll = np.array(reprRandInit)
print reprRandAll
print reprRandAll.shape
# Out:
# [[[  3.22089949   7.56418385   1.9400625  ...,  10.52956723   6.52321742
#      1.43538804]
#   [  2.5032331    5.54495166   4.1080872  ...,   4.74744042   6.23427407
#      8.97063763]]
#
#  [[  5.87716814   2.87243522   3.08575865 ...,   2.10341195   3.60794253
#      2.35811821]
#   [  1.33058741   7.05610894   6.24695231 ...,   7.86359823   6.71264864
#      6.31196167]]
#
#  [[  1.7972651    0.21340634   3.78501038 ...,   4.02433144   6.26992189
#      8.98409398]
#   [  4.64974088   7.57829911   1.0808109  ...,   1.47353937   9.06517805
#      7.61809249]]
#
#  ...,
#  [[  8.22517775   4.52664557   3.68423088 ...,   5.75891281   5.57786826
#      5.50747893]
#   [  8.76606893   5.35780411   3.67487944 ...,   0.21859763   1.39376429
#      1.62443295]]
#
#  [[  7.35063536   7.24648885   5.53051249 ...,   0.36039578   8.94228445
#      4.242923  ]
#   [  4.60473295   3.00691433   4.64305182 ...,   7.52304942   6.87922903
#      5.39012313]]
#
#  [[  3.45264456   7.34794254   8.17333882 ...,   5.63393605   8.10069783
#      4.19871229]
#   [  4.05228339   7.24944345   5.03209281 ...,   3.58715873   8.84741283
#     -1.28667859]]]
# (50, 2, 100)

# %%
# run this cell
import numpy as np
import random

reprRandInit = []
for i in range(50):
    arrayTest = 3 * np.random.randn(2, 100) + 5
    reprRandInit.append(arrayTest)
reprRandAll = np.array(reprRandInit)
reprRandAll.shape
#see above cell
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here

import numpy as np
import random

#create 'reprRandInit' to store values in list
reprRandInit = []
for i in range(50):
    arrayTest = 3 * np.random.randn(2, 100) + 5
    reprRandInit.append(arrayTest)
reprRandAll = np.array(reprRandInit)

fig = pl.figure()
for i in range(50):
    pl.plot(reprRandAll[i][0], reprRandAll[i][1], 'o')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1: Gaussian Distribution of 50 2x100 Numpy Arrays with Mean = 5 and Standard Deviation = 3

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here

import numpy as np
import random

#create 'reprRandInit' to store values in list
newMeanInit = []
for i in range(50):
    newMeanArrayTest = np.random.randn(2, 100) + np.random.randn()
    newMeanInit.append(newMeanArrayTest)
diffMeans = np.array(newMeanInit)

fig = pl.figure()
fig.suptitle('Gaussian Distribution with Different Means of X,Y', fontsize = 16)
for i in range(50):
    pl.plot(diffMeans[i][0], diffMeans[i][1], 'o')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# plot here...
